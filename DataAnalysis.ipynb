# %%
##############################################
#      Subject 1 Data Analysis               #
##############################################

import pandas as pd

##   Get Motion Signals   ##

emg_rest        = pd.read_csv('EMG_S1/DS0106.csv') #data number 106 is Rest signal at trial 1
emg_close       = pd.read_csv('EMG_S1/DS0130.csv') #data number 130 is close at trial 2
emg_thump       = pd.read_csv('EMG_S1/DS0155.csv') #data number 155 is Thump up signal at trial 2
emg_thumplittle = pd.read_csv('EMG_S1/DS0176.csv') #data number 176 is Thump and little finger signal at trial 2

##   Extract signals amplitudes   ##

emg_rest_amp        = emg_rest.iloc       [16:len(emg_rest),0] 
emg_close_amp       = emg_close.iloc      [16:len(emg_close),0] 
emg_thump_amp       = emg_thump.iloc      [16:len(emg_thump),0] 
emg_thumplittle_amp = emg_thumplittle.iloc[16:len(emg_thumplittle),0] 

##   Check Signals Sample number   ##

rest_len         = len(emg_rest_amp)
close_len        = len(emg_close_amp)
thump_len        = len(emg_thump_amp)
thump_little_len = len(emg_thumplittle_amp)

print("Rest, Close, Thump, and ThumpLittle Length's accordingly: ",rest_len,close_len,thump_len,thump_little_len)

#Note that the data is taken on 1.6 sec. window size as from meta data of reading sample period is 0.4milli sec.

##############################################
##############################################
# Out:
# Rest, Close, Thump, and ThumpLittle Length's accordingly:  4000 4000 4000 4000

# %%
##############################################
########Visualize Subject 1 Amplitudes########
##############################################

import matplotlib.pyplot as plt
import numpy as np

#   Visualize The Motion's amplitudes   #

figure, axes = plt.subplots(2, 2, figsize=(10, 5))

x = range(0,rest_len)
axes[0,0].plot(x,emg_rest_amp,label="DS0106")
axes[0,0].set_title("Rest Hand")
axes[0,0].set_yscale("linear")
axes[0,0].set_ylim(0, 70)

x = range(0,close_len)
axes[0,1].plot(x,emg_close_amp,label="DS0130")
axes[0,1].set_title("Close Hand")
axes[0,1].set_yscale("linear")
axes[0,1].set_ylim(0, 70)

x = range(0,thump_len)
axes[1,0].plot(x,emg_thump_amp,label="DS0155")
axes[1,0].set_title("Thump Up")
axes[1,0].set_yscale("linear")
axes[1,0].set_ylim(0, 70)

x = range(0,thump_little_len)
axes[1,1].plot(x,emg_thumplittle_amp,label="DS0176")
axes[1,1].set_title("Thump and Little Finger Up")
axes[1,1].set_yscale("linear")
axes[1,1].set_ylim(0, 70)

for axis in axes.flat:
    axis.set_xlabel('4000 Samples in 1.6 sec.')
    axis.set_ylabel('Amplitudes 0.03922 Volt')              #Scale inspected by applying 2 Volt and reading the average by 51 that corresponds to that

# Adjust spacing between subplots
plt.tight_layout()

# Show the figure
plt.show()

##############################################
##############################################

# %%
##############################################
#      Subject 2 Data Analysis               #
##############################################

import pandas as pd

##   Get Motion Signals   ##

emg_rest2        = pd.read_csv('EMG_S3/DS0006.csv') #data number 06 is Rest signal at trial 1
emg_close2       = pd.read_csv('EMG_S3/DS0030.csv') #data number 30 is close at trial 2
emg_thump2       = pd.read_csv('EMG_S3/DS0055.csv') #data number 55 is Thump up signal at trial 2
emg_thumplittle2 = pd.read_csv('EMG_S2/DS0079.csv') #125 is Thump and little finger signal at trial 2

##   Extract signals amplitudes   ##

emg_rest_amp2        = emg_rest2.iloc       [16:len(emg_rest),0] 
emg_close_amp2       = emg_close2.iloc      [16:len(emg_close),0] 
emg_thump_amp2       = emg_thump2.iloc      [16:len(emg_thump),0] 
emg_thumplittle_amp2 = emg_thumplittle2.iloc[16:len(emg_thumplittle),0] 

##   Check Signals Sample number   ##

rest_len2         = len(emg_rest_amp2)
close_len2        = len(emg_close_amp2)
thump_len2        = len(emg_thump_amp2)
thump_little_len2 = len(emg_thumplittle_amp2)

print("Rest, Close, Thump, and ThumpLittle Length's accordingly: ",rest_len2,close_len2,thump_len2)

#Note that the data is taken on 1.6 sec. window size as from meta data of reading sample period is 0.4milli sec.

##############################################
##############################################
# Out:
# Rest, Close, Thump, and ThumpLittle Length's accordingly:  4000 4000 4000

# %%
##############################################
########Visualize Subject 2 Amplitudes########
##############################################

import matplotlib.pyplot as plt
import numpy as np

#   Visualize The Motion's amplitudes   #

figure2, axes2 = plt.subplots(2, 2, figsize=(10, 5))

x1 = range(0,rest_len2)
axes2[0,0].plot(x,emg_rest_amp2,label="DS006")
axes2[0,0].set_title("Rest Hand")
axes2[0,0].set_yscale("linear")
axes2[0,0].set_ylim(0, 70)

x2 = range(0,close_len2)
axes2[0,1].plot(x,emg_close_amp2,label="DS0030")
axes2[0,1].set_title("Close Hand")
axes2[0,1].set_yscale("linear")
axes2[0,1].set_ylim(0, 70)

x3 = range(0,thump_len2)
axes2[1,0].plot(x,emg_thump_amp2,label="DS0055")
axes2[1,0].set_title("Thump Up")
axes2[1,0].set_yscale("linear")
axes2[1,0].set_ylim(0, 70)


x4 = range(0,thump_little_len2)
axes2[1,1].plot(x,emg_thumplittle_amp2,label="DS0076")
axes2[1,1].set_title("Thump and Little Finger Up")
axes2[1,1].set_yscale("linear")
axes2[1,1].set_ylim(0, 70)


for axis in axes.flat:
    axis.set_xlabel('4000 Samples in 1.6 sec.')
    axis.set_ylabel('Amplitudes 0.03922 Volt')              #Scale inspected by applying 2 Volt and reading the average by 51 that corresponds to that

# Adjust spacing between subplots
plt.tight_layout()

# Show the figure
plt.show()

##############################################
##############################################

# %%
############### Filter by software ###############
import numpy as np
from scipy.signal import butter, sosfiltfilt
import matplotlib.pyplot as plt

# Generate some sample data
fs = 2500  # Sampling frequency
t = np.arange(0, 1.6, 1/fs)
x = np.array(emg_thump_amp,dtype=float)

# Define the bandpass filter parameters
lowcut = 30  # Lower cutoff frequency
highcut = 300  # Upper cutoff frequency
order = 4  # Filter order

# Design the bandpass filter
def butter_bandpass(lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    sos = butter(order, [low, high], btype='band', output='sos')
    return sos

# Apply the bandpass filter
sos = butter_bandpass(lowcut, highcut, fs, order=order)
filtered_x = abs(sosfiltfilt(sos,x ))

# Plot the original and filtered signals
plt.figure(figsize=(10, 6))
plt.plot(t, x, label='Original Signal')
plt.plot(t, filtered_x, label='Filtered Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Bandpass Filter Example')
plt.legend()
plt.grid(True)
plt.show()

# %%
##############################################
##############Subject 1 PSD ##################
##############################################
from scipy import signal #to perform PSD analysis


#from the metadata
sample_period=0.0004
fs=2500

#extract the PSD of each signal

(freq_rest,        psd_rest)        = signal.welch(np.array(emg_rest_amp,dtype=float),fs)
(freq_close,       psd_close)       = signal.welch(np.array(emg_close_amp,dtype=float),fs)
(freq_thump,       psd_thump)       = signal.welch(np.array(emg_thump_amp,dtype=float),fs)
(freq_thumplittle, psd_thumplittle) = signal.welch(np.array(emg_thumplittle_amp,dtype=float),fs)

#   Visualize The PSDs   #

figure, axes = plt.subplots(2, 2, figsize=(15, 7))

x = range(0,rest_len)
axes[0,0].plot(freq_rest,psd_rest,label="DS0106")
axes[0,0].set_title("Rest Hand PSD")
axes[0,0].set_yscale("log")
axes[0,0].set_ylim(0.0001, 1)


axes[0,1].plot(freq_close,psd_close,label="DS0130")
axes[0,1].set_title("Close Hand PSD")
axes[0,1].set_yscale("log")
axes[0,1].set_ylim(0.0001, 1)


axes[1,0].plot(freq_thump,psd_thump,label="DS0155")
axes[1,0].set_title("Thump Up PSD")
axes[1,0].set_yscale("log")
axes[1,0].set_ylim(0.0001, 1)


axes[1,1].plot(freq_thumplittle,psd_thumplittle,label="DS0176")
axes[1,1].set_title("Thump and Little Finger Up PSD")
axes[1,1].set_yscale("log")
axes[1,1].set_ylim(0.0001, 1)


for axis in axes.flat:
    axis.set_xlabel('Freq. Hz')
    axis.set_ylabel('dB/Hz ')
    axis.set_xticks(np.arange(0, 1200, 100))
    
# Adjust spacing between subplots
plt.tight_layout()

# Show the figure
plt.show()

##############################################

##############################################

# %%
##############################################
##############Subject 2 PSD ##################
##############################################
from scipy import signal #to perform PSD analysis


#from the metadata
sample_period=0.0004
fs=2500

#extract the PSD of each signal

(freq_rest2,        psd_rest2)        = signal.welch(np.array(emg_rest_amp2,dtype=float),fs)
(freq_close2,       psd_close2)       = signal.welch(np.array(emg_close_amp2,dtype=float),fs)
(freq_thump2,       psd_thump2)       = signal.welch(np.array(emg_thump_amp2,dtype=float),fs)
(freq_thumplittle2, psd_thumplittle2) = signal.welch(np.array(emg_thumplittle_amp2,dtype=float),fs)

#   Visualize The PSDs   #

figure, axes = plt.subplots(2, 2, figsize=(15, 7))

x = range(0,rest_len)
axes[0,0].plot(freq_rest2,psd_rest2,label="DS0006")
axes[0,0].set_title("Rest Hand PSD")
axes[0,0].set_yscale("log")
axes[0,0].set_ylim(0.0001, 1)


axes[0,1].plot(freq_close2,psd_close2,label="DS0030")
axes[0,1].set_title("Close Hand PSD")
axes[0,1].set_yscale("log")
axes[0,1].set_ylim(0.0001, 1)


axes[1,0].plot(freq_thump2,psd_thump2,label="DS0055")
axes[1,0].set_title("Thump Up PSD")
axes[1,0].set_yscale("log")
axes[1,0].set_ylim(0.0001, 1)


axes[1,1].plot(freq_thumplittle2,psd_thumplittle2,label="DS0076")
axes[1,1].set_title("Thump and Little Finger Up PSD")
axes[1,1].set_yscale("log")
axes[1,1].set_ylim(0.0001, 1)


for axis in axes.flat:
    axis.set_xlabel('Freq. Hz')
    axis.set_ylabel('dB/Hz ')
    axis.set_xticks(np.arange(0, 1200, 100))
    
# Adjust spacing between subplots
plt.tight_layout()

# Show the figure
plt.show()

##############################################
##############################################

# %%
##############################################
##############################################

##   Combine Data Samples in one frame for data validation and Correlation study   ##

from glob import glob 

#get the paths of our data
data_paths_S1=glob("EMG_S1/*.csv")
data_paths_S2=glob("EMG_S2/*.csv")

#get the indices of each motion

rest_indxs        =list(range(0,19+1))
close_indxs       =list(range(20,39+1))
thump_indxs       =list(range(40,59+1))
thumplittle_indxs =list(range(60,79+1))

print("Motion Rest Samples: "+str(len(rest_indxs)))
print("Motion Close Samples: "+str(len(close_indxs)))
print("Motion Thump Samples: "+str(len(thump_indxs)))
print("Motion ThumpLittle Samples: "+str(len(thumplittle_indxs)))

#Combine Motions in one wave each - Subject 1

rest_wave_1, close_wave_1, thump_wave_1, thumpl_wave_1= np.array([]), np.array([]), np.array([]), np.array([])
C=[]
R=[]
T=[]
TL=[]
for j, i in enumerate(data_paths_S1):
    k=pd.read_csv(i)
    k = k.fillna(0)  # fill rows with NaN values
    if j in iter(rest_indxs):
        rest_wave=k.iloc[16:len(k),0]
        R.append(rest_wave)
    if j in iter(close_indxs):
        close_wave=k.iloc[16:len(k),0]
        C.append(close_wave)
    if j in iter(thump_indxs):
        thump_wave=k.iloc[16:len(k),0]
        T.append(thump_wave)
    if j in iter(thumplittle_indxs):
        thumpl_wave=k.iloc[16:len(k),0]
        TL.append(thumpl_wave)
    
Rest_wave_1=np.array(R,dtype=float).reshape(-1)
Close_wave_1=np.array(C,dtype=float).reshape(-1)    
Thumplittle_wave_1=np.array(TL,dtype=float).reshape(-1)
Thump_wave_1=np.array(T,dtype=float).reshape(-1)


print("\nMotion Rest Samples: "+str(len(Rest_wave_1)))
print("Motion Close Samples: "+str(len(Close_wave_1)))
print("Motion Thump Samples: "+str(len(Thump_wave_1)))
print("Motion ThumpLittle Samples: "+str(len(Thumplittle_wave_1)))

#put motions in dictionary

WavesTotal1={
    "Rest":Rest_wave_1,
    "Close":Close_wave_1,
    "Thump_wave":Thump_wave_1,
    "ThumpLittle":Thumplittle_wave_1}

Waves_pd_1 = pd.DataFrame.from_dict(WavesTotal1)


    
#plt.plot(Waves_pd["Rest"])
correlation_matrix_1 = Waves_pd_1.corr()

#Combine Motions in one wave each - Subject 2

rest_wave_2, close_wave_2, thump_wave_2, thumpl_wave_2= np.array([]), np.array([]), np.array([]), np.array([])
C=[]
R=[]
T=[]
TL=[]
for j, i in enumerate(data_paths_S2):
    k=pd.read_csv(i)
    k = k.fillna(0)  # fill rows with NaN values
    if j in iter(rest_indxs):
        rest_wave=k.iloc[16:len(k),0]
        R.append(rest_wave)
    if j in iter(close_indxs):
        close_wave=k.iloc[16:len(k),0]
        C.append(close_wave)
    if j in iter(thump_indxs):
        thump_wave=k.iloc[16:len(k),0]
        T.append(thump_wave)
    if j in iter(thumplittle_indxs):
        thumpl_wave=k.iloc[16:len(k),0]
        TL.append(thumpl_wave)
    
Rest_wave_2=np.array(R,dtype=float).reshape(-1)
Close_wave_2=np.array(C,dtype=float).reshape(-1)    
Thumplittle_wave_2=np.array(TL,dtype=float).reshape(-1)
Thump_wave_2=np.array(T,dtype=float).reshape(-1)


print("\nMotion Rest 2 Samples: "+str(len(Rest_wave_2)))
print("Motion Close 2 Samples: "+str(len(Close_wave_2)))
print("Motion Thump 2 Samples: "+str(len(Thump_wave_2)))
print("Motion ThumpLittle 2 Samples: "+str(len(Thumplittle_wave_2)))

#put motions in dictionary

WavesTotal2={
    "Rest":Rest_wave_2,
    "Close":Close_wave_2,
    "Thump_wave":Thump_wave_2,
    "ThumpLittle":Thumplittle_wave_2}

Waves_pd_2 = pd.DataFrame.from_dict(WavesTotal2)


    
#plt.plot(Waves_pd["Rest"])
correlation_matrix_2 = Waves_pd_2.corr()



##   Correlations between same motion data using subject 1 data  ##

Wave_samples_rest={}
for j,i in enumerate(data_paths_S1[0:20]):
    k=pd.read_csv(i)
    Wave_samples_rest["sample"+str(j)]=np.array(k.iloc[16:len(k),0],dtype=float).reshape(-1)
    
Wave_samples_rest_pd = pd.DataFrame.from_dict(Wave_samples_rest)
correlation_matrix_rest = Wave_samples_rest_pd.corr()
print(correlation_matrix_rest)

Wave_samples_close={}
for j,i in enumerate(data_paths_S1[20:40]):
    k=pd.read_csv(i)
    Wave_samples_close["sample"+str(j)]=np.array(k.iloc[16:len(k),0],dtype=float).reshape(-1)
    
Wave_samples_close_pd = pd.DataFrame.from_dict(Wave_samples_close)
correlation_matrix_close = Wave_samples_close_pd.corr()
print(correlation_matrix_close)

Wave_samples_thump={}
for j,i in enumerate(data_paths_S1[40:60]):
    k=pd.read_csv(i)
    Wave_samples_thump["sample"+str(j)]=np.array(k.iloc[16:len(k),0],dtype=float).reshape(-1)
    
Wave_samples_thump_pd = pd.DataFrame.from_dict(Wave_samples_thump)
correlation_matrix_thump = Wave_samples_thump_pd.corr()
print(correlation_matrix_thump)

Wave_samples_tl={}
for j,i in enumerate(data_paths_S1[60:80]):
    k=pd.read_csv(i)
    Wave_samples_tl["sample"+str(j)]=np.array(k.iloc[16:len(k),0],dtype=float).reshape(-1)
Wave_samples_tl_pd = pd.DataFrame.from_dict(Wave_samples_tl)
correlation_matrix_tl = Wave_samples_tl_pd.corr()
print(correlation_matrix_tl)

plt.plot(range(0,len(Waves_pd["Rest"])) ,Waves_pd["Rest"])
plt.plot(range(0,len(Waves_pd["Close"])) ,Waves_pd["Close"])
plt.plot(range(0,len(Waves_pd["Thump_wave"])) ,Waves_pd["Thump_wave"])
plt.plot(range(0,len(Waves_pd["ThumpLittle"])) ,Waves_pd["ThumpLittle"])


##############################################
##############################################
# Out:
# Motion Rest Samples: 20
# Motion Close Samples: 20
# Motion Thump Samples: 20
# Motion ThumpLittle Samples: 20
#
# Motion Rest Samples: 80000
# Motion Close Samples: 80000
# Motion Thump Samples: 80000
# Motion ThumpLittle Samples: 80000
#
# Motion Rest 2 Samples: 80000
# Motion Close 2 Samples: 80000
# Motion Thump 2 Samples: 80000
# Motion ThumpLittle 2 Samples: 80000
#            sample0   sample1   sample2   sample3   sample4   sample5  \
# sample0   1.000000  0.561198 -0.347448  0.243063 -0.127662 -0.180655
# sample1   0.561198  1.000000 -0.302113  0.102935 -0.023264 -0.261207
# sample2  -0.347448 -0.302113  1.000000 -0.392640  0.343393 -0.243926
# sample3   0.243063  0.102935 -0.392640  1.000000 -0.412717  0.273663
# sample4  -0.127662 -0.023264  0.343393 -0.412717  1.000000 -0.408388
# sample5  -0.180655 -0.261207 -0.243926  0.273663 -0.408388  1.000000
# sample6   0.578349  0.551200 -0.387651  0.301817 -0.188152 -0.167982
# ...

# %%
print("mean correlation between samples in ThumpLittle",np.mean(correlation_matrix_tl))
print("mean correlation between samples in thump",np.mean(correlation_matrix_thump))
print("mean correlation between samples in close",np.mean(correlation_matrix_close))
print("mean correlation between samples in rest",np.mean(correlation_matrix_rest))
print("mean correlation between morions and ThumpLittle",np.mean(correlation_matrix_1["Rest"][1:4]))
close_corr=[]
for j,i in enumerate(correlation_matrix_1["Close"]):
    if j != 1:
        close_corr.append(i)

thump_corr=[]
for j,i in enumerate(correlation_matrix_1["Thump_wave"]):
    if j != 2:
        thump_corr.append(i)

thumplittle_corr=[]
for j,i in enumerate(correlation_matrix_1["ThumpLittle"]):
    if j != 3:
        thumplittle_corr.append(i)
        
print("mean correlation between morions and Close",np.mean(close_corr))
print("mean correlation between morions and Thump",np.mean(thump_corr))
print("mean correlation between morions and ThumpLittle",np.mean(thumplittle_corr))
# Out:
# mean correlation between samples in ThumpLittle 0.05145685318209834
# mean correlation between samples in thump 0.05502940442630404
# mean correlation between samples in close 0.056780801804096726
# mean correlation between samples in rest 0.10636766754586464
# mean correlation between morions and ThumpLittle -0.006164902132725733
# mean correlation between morions and Close -0.008256860723724196
# mean correlation between morions and Thump -0.0026309656897832204
# mean correlation between morions and ThumpLittle 0.0006436754327712393

# %%
######################## features examples 
#########################################
#EMG feature extraction#

#####Common Features########

#Statistical Features#

def mean(x):
    '''Average value of the EMG sample'''
    return np.mean(x,axis=-1)
def std(x):
    '''Standard deviation for data (70% for 1std) about the mean'''
    return np.std(x,axis=-1)
def var(x):
    '''Expected average variability of the data about the mean sum((x-u)^2)/N '''
    return np.var(x,axis=-1)
def rms(x):
    return np.sqrt(np.mean(x**2,axis=-1))
def skewness(x):
    '''Symmetricity and its direction'''
    return stats.skew(x,axis=-1)
def kurtosis(x):
    return stats.kurtosis(x,axis=-1)

#Time Analysis
def ptp(x):
    '''Signal Range'''
    return np.ptp(x,axis=-1)
def minim(x):
    '''Minimum Time Domain'''
    return np.min(x,axis=-1)
def maxim(x):
    '''Maximum Time domain'''
    return np.max(x,axis=-1)
def argminim(x):
    '''minimum index'''
    return np.argmin(x,axis=-1)
def argmaxim(x):
    '''maximum index'''
    return np.argmax(x,axis=-1)
def abs_diff_signal(x):
    return np.sum(np.abs(np.diff(x,axis=-1)),axis=-1)

#Frequecny Domain
def Dominant_freq(x):
    return np.argmax(x,axis=-1)
def band_width(x):
    return 
def concatenate_features(x):
    return np.concatenate((
        mean(x), std(x), ptp(x), var(x), minim(x), maxim(x), argminim(x), argmaxim(x), rms(x), skewness(x) )
        ,axis=-1)

# %%
from scipy import stats, signal
from glob import glob
data_paths_S1=glob("EMG_S1/*.csv")
Rest_SNR=[]
Rest_max_freq=[]
Rest_mean=[]
Rest_std=[]
Rest_kurt=[]
Rest_skewness=[]
Rest_bandwidth=[]
Close_max_freq=[]
Rest_AAC=[]
Close_SNR=[]
Close_std=[]
Close_mean=[]
Close_kurt=[]
Close_skewness=[]
Close_AAC=[]
Close_bandwidth=[]
Thump_SNR=[]
Thump_max_freq=[]
Thump_std=[]
Thump_mean=[]
Thump_kurt=[]
Thump_skewness=[]
Thump_AAC=[]
Thump_bandwidth=[]
Thump_little_SNR=[]
Thump_little_max_freq=[]
Thump_little_mean=[]
Thump_little_std=[]
Thump_little_kurt=[]
Thump_little_skewness=[]
Thump_little_AAC=[]
Thump_little_bandwidth=[]
features={}
for j,i in enumerate(data_paths_S1):
    data_sample =np.array(pd.read_csv(i).iloc[16:4017,0],dtype=float).reshape(1,-1)
    freq , amp = signal.welch(data_sample,2500)
    amp=amp.reshape(-1)
    #Dominant Frequency
    argmax =np.argmax(amp)
    freq_max =freq[argmax]
    #Bandwidth
    indx=[]
    for w,k in enumerate(amp):
        if k >= 0.5 * np.max(amp):
            indx.append(w)
    bandwidth=freq[indx[-1]] - freq[indx[0]]
    #SNR
    sig_power=np.sum(amp[:115])
    noise_power=np.sum(amp[115:len(amp)])
    SNR=sig_power/noise_power
    
    if j < 20:
        Rest_max_freq.append(np.max(freq_max))
        Rest_mean.append(np.mean(data_sample,axis=-1))
        Rest_std.append(np.std(data_sample,axis=-1))
        Rest_kurt.append(stats.kurtosis(data_sample,axis=-1))
        Rest_skewness.append(stats.skew(data_sample,axis=-1))
        Rest_AAC.append(np.sum(abs(np.diff(data_sample , axis = 1)), axis = -1 ) / len(data_sample))
        Rest_bandwidth.append(bandwidth)
        Rest_SNR.append(SNR)

    if 20 <= j < 40:
        Close_max_freq.append(np.max(freq_max))
        Close_mean.append(np.mean(data_sample,axis=-1))
        Close_std.append(np.std(data_sample,axis=-1))
        Close_kurt.append(stats.kurtosis(data_sample,axis=-1))
        Close_skewness.append(stats.skew(data_sample,axis=-1))
        Close_AAC.append(np.sum(abs(np.diff(data_sample , axis = 1)), axis = -1 ) / len(data_sample))
        Close_bandwidth.append(bandwidth)
        Close_SNR.append(SNR)

    if 40 <= j < 60:
        Thump_max_freq.append(np.max(freq_max))
        Thump_mean.append(np.mean(data_sample,axis=-1))
        Thump_std.append(np.std(data_sample,axis=-1))
        Thump_kurt.append(stats.kurtosis(data_sample,axis=-1))
        Thump_skewness.append(stats.skew(data_sample,axis=-1))
        Thump_AAC.append(np.sum(abs(np.diff(data_sample , axis = 1)), axis = -1 ) / len(data_sample))
        Thump_bandwidth.append(bandwidth)
        Thump_SNR.append(SNR)
    if 60 <= j < 80:
        Thump_little_max_freq.append(np.max(freq_max))
        Thump_little_mean.append(np.mean(data_sample,axis=-1))
        Thump_little_std.append(np.std(data_sample,axis=-1))
        Thump_little_kurt.append(stats.kurtosis(data_sample,axis=-1))
        Thump_little_skewness.append(stats.skew(data_sample,axis=-1))
        Thump_little_AAC.append(np.sum(abs(np.diff(data_sample , axis = 1)), axis = -1 ) / len(data_sample))
        Thump_little_bandwidth.append(bandwidth)
        Thump_little_SNR.append(SNR)

# %%
Data_features={"Rest_Featuers":{"Rest_mean":{"average":np.mean(Rest_mean),"Deviation":np.std(Rest_mean)},
               "Rest_std":{"average":np.mean(Rest_std),"Deviation":np.std(Rest_std)},
               "Rest_kurt":{"average":np.mean(Rest_kurt),"Deviation":np.std(Rest_kurt)},
               "Rest_skewness":{"average":np.mean(Rest_skewness),"Deviation":np.std(Rest_skewness)},
               "Rest_AAC":{"average":np.mean(Rest_AAC),"Deviation":np.std(Rest_AAC)},
               "Rest_bandwidth":{"average":np.mean(Rest_bandwidth),"Deviation":np.std(Rest_bandwidth)},
               "Rest_max_freq":{"average":np.mean(Rest_max_freq),"Deviation":np.std(Rest_max_freq)},
               "Rest_SNR":{"average":np.mean(Rest_SNR),"Deviation":np.std(Rest_SNR)} },
               
               "Thump_Features":{"Thump_mean":{"average":np.mean(Thump_mean),"Deviation":np.std(Thump_mean)},
               "Thump_std":{"average":np.mean(Thump_std),"Deviation":np.std(Thump_std)},
               "Thump_kurt":{"average":np.mean(Thump_kurt),"Deviation":np.std(Thump_kurt)},
               "Rest_skewness":{"average":np.mean(Thump_skewness),"Deviation":np.std(Thump_skewness)},
               "Thump_AAC":{"average":np.mean(Thump_AAC),"Deviation":np.std(Thump_AAC)},
               "Thump_bandwidth":{"average":np.mean(Thump_bandwidth),"Deviation":np.std(Thump_bandwidth)},
               "Thump_max_freq":{"average":np.mean(Thump_max_freq),"Deviation":np.std(Thump_max_freq)},
               "Thump_SNR":{"average":np.mean(Thump_SNR),"Deviation":np.std(Thump_SNR)} },
               
               "Close_Features":{"Thump_mean":{"average":np.mean(Close_mean),"Deviation":np.std(Close_mean)},
               "Close_std":{"average":np.mean(Close_std),"Deviation":np.std(Close_std)},
               "Close_kurt":{"average":np.mean(Close_kurt),"Deviation":np.std(Close_kurt)},
               "Close_skewness":{"average":np.mean(Close_skewness),"Deviation":np.std(Close_skewness)},
               "Close_AAC":{"average":np.mean(Close_AAC),"Deviation":np.std(Close_AAC)},
               "Close_bandwidth":{"average":np.mean(Close_bandwidth),"Deviation":np.std(Close_bandwidth)},
               "Close_max_freq":{"average":np.mean(Close_max_freq),"Deviation":np.std(Close_max_freq)},
               "Close_SNR":{"average":np.mean(Close_SNR),"Deviation":np.std(Close_SNR)} },
               "Thump_little_Features":{"Thump_mean":{"average":np.mean(Thump_little_mean),"Deviation":np.std(Thump_little_mean)},
               "Thump_little_std":{"average":np.mean(Thump_little_std),"Deviation":np.std(Thump_little_std)},
               "Thump_little_kurt":{"average":np.mean(Thump_little_kurt),"Deviation":np.std(Thump_little_kurt)},
               "Thump_little_skewness":{"average":np.mean(Thump_little_skewness),"Deviation":np.std(Thump_little_skewness)},
               "Thump_little_AAC":{"average":np.mean(Thump_little_AAC),"Deviation":np.std(Thump_little_AAC)},
               "Thump_little_bandwidth":{"average":np.mean(Thump_little_bandwidth),"Deviation":np.std(Thump_little_bandwidth)},
               "Thump_little_max_freq":{"average":np.mean(Thump_little_max_freq),"Deviation":np.std(Thump_little_max_freq)},
               "Thump_little_SNR":{"average":np.mean(Thump_little_SNR),"Deviation":np.std(Thump_little_SNR)} } }
